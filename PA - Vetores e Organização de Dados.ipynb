# %%
nomes = ["Ana", "Carlos", "Mariana", "João", "Fernanda"]


print("Lista de nomes:")
for nome in nomes:
    print(nome)


print("\nPrimeiro nome:", nomes[0])
print("Último nome:", nomes[-1])
# Out:
# Lista de nomes:
# Ana
# Carlos
# Mariana
# João
# Fernanda
#
# Primeiro nome: Ana
# Último nome: Fernanda
